# %% [markdown]
# <center><h1>SaRLVision Generating GIFs</h1>
# <h2>Matthias Bartolo</h2>
#
# </center>

# %% [markdown]
# **<h3> Package Imports </h3>**

# %%
import cv2

# %%
import SaRLVision as srlv
import gymnasium as gym

from SaRLVision.utils import *
from SaRLVision.agents import *
# Out:
# CUDA is available! Using GPU for computations.

# %% [markdown]
# **<h3> Defining Classes </h3>**

# %%
classes = ['cat', 'bird', 'motorbike', 'diningtable', 'train', 'tvmonitor', 'bus', 'horse', 'car', 'pottedplant', 'person', 'chair', 'boat', 'bottle', 'bicycle', 'dog', 'aeroplane', 'cow', 'sheep', 'sofa']
print(classes)
print('\033[93m' + 'Number of classes: ' + '\033[0m' + str(len(classes)))
# Out:
# ['cat', 'bird', 'motorbike', 'diningtable', 'train', 'tvmonitor', 'bus', 'horse', 'car', 'pottedplant', 'person', 'chair', 'boat', 'bottle', 'bicycle', 'dog', 'aeroplane', 'cow', 'sheep', 'sofa']
# Number of classes: 20

# %% [markdown]
# **<h3> Environment Creation </h3>**
#
# **<h4> Render modes </h4>**
# - `human`: Displays the environment with the current bounding box and action being taken by the agent.
# - `trigger_image`: Displays the environment with the current bounding box and action being taken by the agent, as well as the `Inhibition of Return (IOR)` trigger mark.
# - `bbox`: Displays the environment with the current bounding box and action being taken by the agent, without the image as the background.
# - `rgb_array`: Returns the current frame of the environment as a numpy array.
# - `None`: No rendering is done.
#
# `Note`: In the environment, training mode, the ground truth bounding boxes and training information is also displayed. To change modes: `env.train()`, `env.eval()` and `env.test()`.

# %%
# Defining render modes
render_modes = ['human', 'trigger_image', 'bbox']

# Defining the number of gifs per class
num_gifs = 10

# Iterating over the classes
for current_class in classes:
    # Printing the class name
    print('*'*50)
    print('\033[92m' + 'Executing for class: ' + current_class + '\033[0m')
    print('*'*50)

    # Setting the environment configuration
    env_config = {'dataset': '../Datasets/PascalVOC2007Dataset',
                'dataset_year': '2007',
                'dataset_image_set': 'test',
                'feature_extractor': VGG16FeatureExtractor(), 
                'target_size': VGG16_TARGET_SIZE,
                'current_class': current_class,
                'use_sara': False,
                'threshold': 0.5,
                'render_mode': render_modes[random.randint(0, len(render_modes) - 1)], # Randomly selecting a render mode
                }

    # Creating the environment
    env = gym.make('DetectionEnv-v0-Test', env_config=env_config)

    # Setting name
    name = "D3QN - Random Explore - VGG16 - No SaRa"

    # Creating the Replay_Buffer
    replay_buffer = Replay_Buffer(env)

    # Creating the D3QN agent
    dqn_agent = DoubleDuelingDQNAgent(env, replay_buffer, name=name, exploration_mode=RANDOM_EXPLORE)

    # Loading the model
    dqn_agent.load(path="evaluation_models/" + name + '/' + current_class)

    # Randomly selecting either 1 or 0
    random_action = random.randint(0, 1)

    # If the random action is 1, then set environment mode to test
    if random_action == 1:
        env.test()
        
    # Setting the epsilon to 0
    dqn_agent.epsilon = 0.0

    # Generating the GIFs
    # Setting the path
    path = "../../Diagrams/GIFs/" + current_class + "/"

    # Creating the directory
    os.makedirs(path, exist_ok=True)

    # Iterating over the number of gifs
    for i in range(num_gifs):
        dqn_agent.save_gif(file_path=path, gif_filename=current_class + "_GIF_" + str(i)+".gif")

    # Closing the environment
    env.close()
    
    # Memory Cleaning
    del env, replay_buffer, dqn_agent
# Out:
# **************************************************
# Executing for class: cat
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007Dataset\VOCtest_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007Dataset\VOCtest_06-Nov-2007.tar to ../Datasets/PascalVOC2007Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 7632
# Current Class: cat
# GIF saved to: ../../Diagrams/GIFs/cat/cat_GIF_0.gif
# GIF saved to: ../../Diagrams/GIFs/cat/cat_GIF_1.gif
# GIF saved to: ../../Diagrams/GIFs/cat/cat_GIF_2.gif
# GIF saved to: ../../Diagrams/GIFs/cat/cat_GIF_3.gif
# GIF saved to: ../../Diagrams/GIFs/cat/cat_GIF_4.gif
# GIF saved to: ../../Diagrams/GIFs/cat/cat_GIF_5.gif
# GIF saved to: ../../Diagrams/GIFs/cat/cat_GIF_6.gif
# GIF saved to: ../../Diagrams/GIFs/cat/cat_GIF_7.gif
# GIF saved to: ../../Diagrams/GIFs/cat/cat_GIF_8.gif
# GIF saved to: ../../Diagrams/GIFs/cat/cat_GIF_9.gif
# **************************************************
# Executing for class: bird
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007Dataset\VOCtest_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007Dataset\VOCtest_06-Nov-2007.tar to ../Datasets/PascalVOC2007Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 7632
# Current Class: bird
# GIF saved to: ../../Diagrams/GIFs/bird/bird_GIF_0.gif
# GIF saved to: ../../Diagrams/GIFs/bird/bird_GIF_1.gif
# GIF saved to: ../../Diagrams/GIFs/bird/bird_GIF_2.gif
# GIF saved to: ../../Diagrams/GIFs/bird/bird_GIF_3.gif
# GIF saved to: ../../Diagrams/GIFs/bird/bird_GIF_4.gif
# GIF saved to: ../../Diagrams/GIFs/bird/bird_GIF_5.gif
# GIF saved to: ../../Diagrams/GIFs/bird/bird_GIF_6.gif
# GIF saved to: ../../Diagrams/GIFs/bird/bird_GIF_7.gif
# GIF saved to: ../../Diagrams/GIFs/bird/bird_GIF_8.gif
# GIF saved to: ../../Diagrams/GIFs/bird/bird_GIF_9.gif
# **************************************************
# Executing for class: motorbike
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007Dataset\VOCtest_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007Dataset\VOCtest_06-Nov-2007.tar to ../Datasets/PascalVOC2007Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 7632
# Current Class: motorbike
# GIF saved to: ../../Diagrams/GIFs/motorbike/motorbike_GIF_0.gif
# GIF saved to: ../../Diagrams/GIFs/motorbike/motorbike_GIF_1.gif
# GIF saved to: ../../Diagrams/GIFs/motorbike/motorbike_GIF_2.gif
# GIF saved to: ../../Diagrams/GIFs/motorbike/motorbike_GIF_3.gif
# GIF saved to: ../../Diagrams/GIFs/motorbike/motorbike_GIF_4.gif
# GIF saved to: ../../Diagrams/GIFs/motorbike/motorbike_GIF_5.gif
# GIF saved to: ../../Diagrams/GIFs/motorbike/motorbike_GIF_6.gif
# GIF saved to: ../../Diagrams/GIFs/motorbike/motorbike_GIF_7.gif
# GIF saved to: ../../Diagrams/GIFs/motorbike/motorbike_GIF_8.gif
# GIF saved to: ../../Diagrams/GIFs/motorbike/motorbike_GIF_9.gif
# **************************************************
# Executing for class: diningtable
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007Dataset\VOCtest_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007Dataset\VOCtest_06-Nov-2007.tar to ../Datasets/PascalVOC2007Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 7632
# Current Class: diningtable
# GIF saved to: ../../Diagrams/GIFs/diningtable/diningtable_GIF_0.gif
# GIF saved to: ../../Diagrams/GIFs/diningtable/diningtable_GIF_1.gif
# GIF saved to: ../../Diagrams/GIFs/diningtable/diningtable_GIF_2.gif
# GIF saved to: ../../Diagrams/GIFs/diningtable/diningtable_GIF_3.gif
# GIF saved to: ../../Diagrams/GIFs/diningtable/diningtable_GIF_4.gif
# GIF saved to: ../../Diagrams/GIFs/diningtable/diningtable_GIF_5.gif
# GIF saved to: ../../Diagrams/GIFs/diningtable/diningtable_GIF_6.gif
# GIF saved to: ../../Diagrams/GIFs/diningtable/diningtable_GIF_7.gif
# GIF saved to: ../../Diagrams/GIFs/diningtable/diningtable_GIF_8.gif
# GIF saved to: ../../Diagrams/GIFs/diningtable/diningtable_GIF_9.gif
# **************************************************
# Executing for class: train
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007Dataset\VOCtest_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007Dataset\VOCtest_06-Nov-2007.tar to ../Datasets/PascalVOC2007Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 7632
# Current Class: train
# GIF saved to: ../../Diagrams/GIFs/train/train_GIF_0.gif
# GIF saved to: ../../Diagrams/GIFs/train/train_GIF_1.gif
# GIF saved to: ../../Diagrams/GIFs/train/train_GIF_2.gif
# GIF saved to: ../../Diagrams/GIFs/train/train_GIF_3.gif
# GIF saved to: ../../Diagrams/GIFs/train/train_GIF_4.gif
# GIF saved to: ../../Diagrams/GIFs/train/train_GIF_5.gif
# GIF saved to: ../../Diagrams/GIFs/train/train_GIF_6.gif
# GIF saved to: ../../Diagrams/GIFs/train/train_GIF_7.gif
# GIF saved to: ../../Diagrams/GIFs/train/train_GIF_8.gif
# GIF saved to: ../../Diagrams/GIFs/train/train_GIF_9.gif
# **************************************************
# Executing for class: tvmonitor
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007Dataset\VOCtest_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007Dataset\VOCtest_06-Nov-2007.tar to ../Datasets/PascalVOC2007Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 7632
# Current Class: tvmonitor
# GIF saved to: ../../Diagrams/GIFs/tvmonitor/tvmonitor_GIF_0.gif
# GIF saved to: ../../Diagrams/GIFs/tvmonitor/tvmonitor_GIF_1.gif
# GIF saved to: ../../Diagrams/GIFs/tvmonitor/tvmonitor_GIF_2.gif
# GIF saved to: ../../Diagrams/GIFs/tvmonitor/tvmonitor_GIF_3.gif
# GIF saved to: ../../Diagrams/GIFs/tvmonitor/tvmonitor_GIF_4.gif
# GIF saved to: ../../Diagrams/GIFs/tvmonitor/tvmonitor_GIF_5.gif
# GIF saved to: ../../Diagrams/GIFs/tvmonitor/tvmonitor_GIF_6.gif
# GIF saved to: ../../Diagrams/GIFs/tvmonitor/tvmonitor_GIF_7.gif
# GIF saved to: ../../Diagrams/GIFs/tvmonitor/tvmonitor_GIF_8.gif
# GIF saved to: ../../Diagrams/GIFs/tvmonitor/tvmonitor_GIF_9.gif
# **************************************************
# Executing for class: bus
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007Dataset\VOCtest_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007Dataset\VOCtest_06-Nov-2007.tar to ../Datasets/PascalVOC2007Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 7632
# Current Class: bus
# GIF saved to: ../../Diagrams/GIFs/bus/bus_GIF_0.gif
# GIF saved to: ../../Diagrams/GIFs/bus/bus_GIF_1.gif
# GIF saved to: ../../Diagrams/GIFs/bus/bus_GIF_2.gif
# GIF saved to: ../../Diagrams/GIFs/bus/bus_GIF_3.gif
# GIF saved to: ../../Diagrams/GIFs/bus/bus_GIF_4.gif
# GIF saved to: ../../Diagrams/GIFs/bus/bus_GIF_5.gif
# GIF saved to: ../../Diagrams/GIFs/bus/bus_GIF_6.gif
# GIF saved to: ../../Diagrams/GIFs/bus/bus_GIF_7.gif
# GIF saved to: ../../Diagrams/GIFs/bus/bus_GIF_8.gif
# GIF saved to: ../../Diagrams/GIFs/bus/bus_GIF_9.gif
# **************************************************
# Executing for class: horse
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007Dataset\VOCtest_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007Dataset\VOCtest_06-Nov-2007.tar to ../Datasets/PascalVOC2007Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 7632
# Current Class: horse
# GIF saved to: ../../Diagrams/GIFs/horse/horse_GIF_0.gif
# GIF saved to: ../../Diagrams/GIFs/horse/horse_GIF_1.gif
# GIF saved to: ../../Diagrams/GIFs/horse/horse_GIF_2.gif
# GIF saved to: ../../Diagrams/GIFs/horse/horse_GIF_3.gif
# GIF saved to: ../../Diagrams/GIFs/horse/horse_GIF_4.gif
# GIF saved to: ../../Diagrams/GIFs/horse/horse_GIF_5.gif
# GIF saved to: ../../Diagrams/GIFs/horse/horse_GIF_6.gif
# GIF saved to: ../../Diagrams/GIFs/horse/horse_GIF_7.gif
# GIF saved to: ../../Diagrams/GIFs/horse/horse_GIF_8.gif
# GIF saved to: ../../Diagrams/GIFs/horse/horse_GIF_9.gif
# **************************************************
# Executing for class: car
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007Dataset\VOCtest_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007Dataset\VOCtest_06-Nov-2007.tar to ../Datasets/PascalVOC2007Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 7632
# Current Class: car
# GIF saved to: ../../Diagrams/GIFs/car/car_GIF_0.gif
# GIF saved to: ../../Diagrams/GIFs/car/car_GIF_1.gif
# GIF saved to: ../../Diagrams/GIFs/car/car_GIF_2.gif
# GIF saved to: ../../Diagrams/GIFs/car/car_GIF_3.gif
# GIF saved to: ../../Diagrams/GIFs/car/car_GIF_4.gif
# GIF saved to: ../../Diagrams/GIFs/car/car_GIF_5.gif
# GIF saved to: ../../Diagrams/GIFs/car/car_GIF_6.gif
# GIF saved to: ../../Diagrams/GIFs/car/car_GIF_7.gif
# GIF saved to: ../../Diagrams/GIFs/car/car_GIF_8.gif
# GIF saved to: ../../Diagrams/GIFs/car/car_GIF_9.gif
# **************************************************
# Executing for class: pottedplant
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007Dataset\VOCtest_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007Dataset\VOCtest_06-Nov-2007.tar to ../Datasets/PascalVOC2007Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 7632
# Current Class: pottedplant
# GIF saved to: ../../Diagrams/GIFs/pottedplant/pottedplant_GIF_0.gif
# GIF saved to: ../../Diagrams/GIFs/pottedplant/pottedplant_GIF_1.gif
# GIF saved to: ../../Diagrams/GIFs/pottedplant/pottedplant_GIF_2.gif
# GIF saved to: ../../Diagrams/GIFs/pottedplant/pottedplant_GIF_3.gif
# GIF saved to: ../../Diagrams/GIFs/pottedplant/pottedplant_GIF_4.gif
# GIF saved to: ../../Diagrams/GIFs/pottedplant/pottedplant_GIF_5.gif
# GIF saved to: ../../Diagrams/GIFs/pottedplant/pottedplant_GIF_6.gif
# GIF saved to: ../../Diagrams/GIFs/pottedplant/pottedplant_GIF_7.gif
# GIF saved to: ../../Diagrams/GIFs/pottedplant/pottedplant_GIF_8.gif
# GIF saved to: ../../Diagrams/GIFs/pottedplant/pottedplant_GIF_9.gif
# **************************************************
# Executing for class: person
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007Dataset\VOCtest_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007Dataset\VOCtest_06-Nov-2007.tar to ../Datasets/PascalVOC2007Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 7632
# Current Class: person
# GIF saved to: ../../Diagrams/GIFs/person/person_GIF_0.gif
# GIF saved to: ../../Diagrams/GIFs/person/person_GIF_1.gif
# GIF saved to: ../../Diagrams/GIFs/person/person_GIF_2.gif
# GIF saved to: ../../Diagrams/GIFs/person/person_GIF_3.gif
# GIF saved to: ../../Diagrams/GIFs/person/person_GIF_4.gif
# GIF saved to: ../../Diagrams/GIFs/person/person_GIF_5.gif
# GIF saved to: ../../Diagrams/GIFs/person/person_GIF_6.gif
# GIF saved to: ../../Diagrams/GIFs/person/person_GIF_7.gif
# GIF saved to: ../../Diagrams/GIFs/person/person_GIF_8.gif
# GIF saved to: ../../Diagrams/GIFs/person/person_GIF_9.gif
# **************************************************
# Executing for class: chair
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007Dataset\VOCtest_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007Dataset\VOCtest_06-Nov-2007.tar to ../Datasets/PascalVOC2007Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 7632
# Current Class: chair
# GIF saved to: ../../Diagrams/GIFs/chair/chair_GIF_0.gif
# GIF saved to: ../../Diagrams/GIFs/chair/chair_GIF_1.gif
# GIF saved to: ../../Diagrams/GIFs/chair/chair_GIF_2.gif
# GIF saved to: ../../Diagrams/GIFs/chair/chair_GIF_3.gif
# GIF saved to: ../../Diagrams/GIFs/chair/chair_GIF_4.gif
# GIF saved to: ../../Diagrams/GIFs/chair/chair_GIF_5.gif
# GIF saved to: ../../Diagrams/GIFs/chair/chair_GIF_6.gif
# GIF saved to: ../../Diagrams/GIFs/chair/chair_GIF_7.gif
# GIF saved to: ../../Diagrams/GIFs/chair/chair_GIF_8.gif
# GIF saved to: ../../Diagrams/GIFs/chair/chair_GIF_9.gif
# **************************************************
# Executing for class: boat
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007Dataset\VOCtest_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007Dataset\VOCtest_06-Nov-2007.tar to ../Datasets/PascalVOC2007Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 7632
# Current Class: boat
# GIF saved to: ../../Diagrams/GIFs/boat/boat_GIF_0.gif
# GIF saved to: ../../Diagrams/GIFs/boat/boat_GIF_1.gif
# GIF saved to: ../../Diagrams/GIFs/boat/boat_GIF_2.gif
# GIF saved to: ../../Diagrams/GIFs/boat/boat_GIF_3.gif
# GIF saved to: ../../Diagrams/GIFs/boat/boat_GIF_4.gif
# GIF saved to: ../../Diagrams/GIFs/boat/boat_GIF_5.gif
# GIF saved to: ../../Diagrams/GIFs/boat/boat_GIF_6.gif
# GIF saved to: ../../Diagrams/GIFs/boat/boat_GIF_7.gif
# GIF saved to: ../../Diagrams/GIFs/boat/boat_GIF_8.gif
# GIF saved to: ../../Diagrams/GIFs/boat/boat_GIF_9.gif
# **************************************************
# Executing for class: bottle
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007Dataset\VOCtest_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007Dataset\VOCtest_06-Nov-2007.tar to ../Datasets/PascalVOC2007Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 7632
# Current Class: bottle
# GIF saved to: ../../Diagrams/GIFs/bottle/bottle_GIF_0.gif
# GIF saved to: ../../Diagrams/GIFs/bottle/bottle_GIF_1.gif
# GIF saved to: ../../Diagrams/GIFs/bottle/bottle_GIF_2.gif
# GIF saved to: ../../Diagrams/GIFs/bottle/bottle_GIF_3.gif
# GIF saved to: ../../Diagrams/GIFs/bottle/bottle_GIF_4.gif
# GIF saved to: ../../Diagrams/GIFs/bottle/bottle_GIF_5.gif
# GIF saved to: ../../Diagrams/GIFs/bottle/bottle_GIF_6.gif
# GIF saved to: ../../Diagrams/GIFs/bottle/bottle_GIF_7.gif
# GIF saved to: ../../Diagrams/GIFs/bottle/bottle_GIF_8.gif
# GIF saved to: ../../Diagrams/GIFs/bottle/bottle_GIF_9.gif
# **************************************************
# Executing for class: bicycle
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007Dataset\VOCtest_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007Dataset\VOCtest_06-Nov-2007.tar to ../Datasets/PascalVOC2007Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 7632
# Current Class: bicycle
# GIF saved to: ../../Diagrams/GIFs/bicycle/bicycle_GIF_0.gif
# GIF saved to: ../../Diagrams/GIFs/bicycle/bicycle_GIF_1.gif
# GIF saved to: ../../Diagrams/GIFs/bicycle/bicycle_GIF_2.gif
# GIF saved to: ../../Diagrams/GIFs/bicycle/bicycle_GIF_3.gif
# GIF saved to: ../../Diagrams/GIFs/bicycle/bicycle_GIF_4.gif
# GIF saved to: ../../Diagrams/GIFs/bicycle/bicycle_GIF_5.gif
# GIF saved to: ../../Diagrams/GIFs/bicycle/bicycle_GIF_6.gif
# GIF saved to: ../../Diagrams/GIFs/bicycle/bicycle_GIF_7.gif
# GIF saved to: ../../Diagrams/GIFs/bicycle/bicycle_GIF_8.gif
# GIF saved to: ../../Diagrams/GIFs/bicycle/bicycle_GIF_9.gif
# **************************************************
# Executing for class: dog
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007Dataset\VOCtest_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007Dataset\VOCtest_06-Nov-2007.tar to ../Datasets/PascalVOC2007Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 7632
# Current Class: dog
# GIF saved to: ../../Diagrams/GIFs/dog/dog_GIF_0.gif
# GIF saved to: ../../Diagrams/GIFs/dog/dog_GIF_1.gif
# GIF saved to: ../../Diagrams/GIFs/dog/dog_GIF_2.gif
# GIF saved to: ../../Diagrams/GIFs/dog/dog_GIF_3.gif
# GIF saved to: ../../Diagrams/GIFs/dog/dog_GIF_4.gif
# GIF saved to: ../../Diagrams/GIFs/dog/dog_GIF_5.gif
# GIF saved to: ../../Diagrams/GIFs/dog/dog_GIF_6.gif
# GIF saved to: ../../Diagrams/GIFs/dog/dog_GIF_7.gif
# GIF saved to: ../../Diagrams/GIFs/dog/dog_GIF_8.gif
# GIF saved to: ../../Diagrams/GIFs/dog/dog_GIF_9.gif
# **************************************************
# Executing for class: aeroplane
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007Dataset\VOCtest_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007Dataset\VOCtest_06-Nov-2007.tar to ../Datasets/PascalVOC2007Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 7632
# Current Class: aeroplane
# GIF saved to: ../../Diagrams/GIFs/aeroplane/aeroplane_GIF_0.gif
# GIF saved to: ../../Diagrams/GIFs/aeroplane/aeroplane_GIF_1.gif
# GIF saved to: ../../Diagrams/GIFs/aeroplane/aeroplane_GIF_2.gif
# GIF saved to: ../../Diagrams/GIFs/aeroplane/aeroplane_GIF_3.gif
# GIF saved to: ../../Diagrams/GIFs/aeroplane/aeroplane_GIF_4.gif
# GIF saved to: ../../Diagrams/GIFs/aeroplane/aeroplane_GIF_5.gif
# GIF saved to: ../../Diagrams/GIFs/aeroplane/aeroplane_GIF_6.gif
# GIF saved to: ../../Diagrams/GIFs/aeroplane/aeroplane_GIF_7.gif
# GIF saved to: ../../Diagrams/GIFs/aeroplane/aeroplane_GIF_8.gif
# GIF saved to: ../../Diagrams/GIFs/aeroplane/aeroplane_GIF_9.gif
# **************************************************
# Executing for class: cow
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007Dataset\VOCtest_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007Dataset\VOCtest_06-Nov-2007.tar to ../Datasets/PascalVOC2007Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 7632
# Current Class: cow
# GIF saved to: ../../Diagrams/GIFs/cow/cow_GIF_0.gif
# GIF saved to: ../../Diagrams/GIFs/cow/cow_GIF_1.gif
# GIF saved to: ../../Diagrams/GIFs/cow/cow_GIF_2.gif
# GIF saved to: ../../Diagrams/GIFs/cow/cow_GIF_3.gif
# GIF saved to: ../../Diagrams/GIFs/cow/cow_GIF_4.gif
# GIF saved to: ../../Diagrams/GIFs/cow/cow_GIF_5.gif
# GIF saved to: ../../Diagrams/GIFs/cow/cow_GIF_6.gif
# GIF saved to: ../../Diagrams/GIFs/cow/cow_GIF_7.gif
# GIF saved to: ../../Diagrams/GIFs/cow/cow_GIF_8.gif
# GIF saved to: ../../Diagrams/GIFs/cow/cow_GIF_9.gif
# **************************************************
# Executing for class: sheep
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007Dataset\VOCtest_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007Dataset\VOCtest_06-Nov-2007.tar to ../Datasets/PascalVOC2007Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 7632
# Current Class: sheep
# GIF saved to: ../../Diagrams/GIFs/sheep/sheep_GIF_0.gif
# GIF saved to: ../../Diagrams/GIFs/sheep/sheep_GIF_1.gif
# GIF saved to: ../../Diagrams/GIFs/sheep/sheep_GIF_2.gif
# GIF saved to: ../../Diagrams/GIFs/sheep/sheep_GIF_3.gif
# GIF saved to: ../../Diagrams/GIFs/sheep/sheep_GIF_4.gif
# GIF saved to: ../../Diagrams/GIFs/sheep/sheep_GIF_5.gif
# GIF saved to: ../../Diagrams/GIFs/sheep/sheep_GIF_6.gif
# GIF saved to: ../../Diagrams/GIFs/sheep/sheep_GIF_7.gif
# GIF saved to: ../../Diagrams/GIFs/sheep/sheep_GIF_8.gif
# GIF saved to: ../../Diagrams/GIFs/sheep/sheep_GIF_9.gif
# **************************************************
# Executing for class: sofa
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007Dataset\VOCtest_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007Dataset\VOCtest_06-Nov-2007.tar to ../Datasets/PascalVOC2007Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 7632
# Current Class: sofa
# GIF saved to: ../../Diagrams/GIFs/sofa/sofa_GIF_0.gif
# GIF saved to: ../../Diagrams/GIFs/sofa/sofa_GIF_1.gif
# GIF saved to: ../../Diagrams/GIFs/sofa/sofa_GIF_2.gif
# GIF saved to: ../../Diagrams/GIFs/sofa/sofa_GIF_3.gif
# GIF saved to: ../../Diagrams/GIFs/sofa/sofa_GIF_4.gif
# GIF saved to: ../../Diagrams/GIFs/sofa/sofa_GIF_5.gif
# GIF saved to: ../../Diagrams/GIFs/sofa/sofa_GIF_6.gif
# GIF saved to: ../../Diagrams/GIFs/sofa/sofa_GIF_7.gif
# GIF saved to: ../../Diagrams/GIFs/sofa/sofa_GIF_8.gif
# GIF saved to: ../../Diagrams/GIFs/sofa/sofa_GIF_9.gif
