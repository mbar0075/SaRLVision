# %% [markdown]
# <center><h1>SaRLVision Reinforcement Learning Training</h1>
# <h2>Matthias Bartolo</h2>
#
# </center>

# %% [markdown]
# **<h3> Package Imports </h3>**

# %%
import SaRLVision as srlv
import gymnasium as gym

from SaRLVision.utils import *
from SaRLVision.agents import *
# Out:
# CUDA is available! Using GPU for computations.

# %% [markdown]
# **<h3> Defining Classes </h3>**

# %%
classes = ['cat', 'bird', 'motorbike', 'diningtable', 'train', 'tvmonitor', 'bus', 'horse', 'car', 'pottedplant', 'person', 'chair', 'boat', 'bottle', 'bicycle', 'dog', 'aeroplane', 'cow', 'sheep', 'sofa']
print(classes)
print('\033[93m' + 'Number of classes: ' + '\033[0m' + str(len(classes)))
# Out:
# ['cat', 'bird', 'motorbike', 'diningtable', 'train', 'tvmonitor', 'bus', 'horse', 'car', 'pottedplant', 'person', 'chair', 'boat', 'bottle', 'bicycle', 'dog', 'aeroplane', 'cow', 'sheep', 'sofa']
# Number of classes: 20

# %% [markdown]
# **<h3> Training Experiment 1: Exploration and Saliency Ranking </h3>**

# %% [markdown]
# **<h4> Normal DQN Agent - Random Exploration - VGG16 - No SaRa </h4>**

# %%
# Iterating over the classes
for current_class in classes:
    # Printing the class name
    print('*'*50)
    print('\033[92m' + 'Executing for class: ' + current_class + '\033[0m')
    print('*'*50)

    # Setting the environment configuration
    env_config = {'dataset': '../Datasets/PascalVOC2007_2012Dataset',
                'dataset_year': '2007+2012',
                'dataset_image_set': 'train',
                'feature_extractor':VGG16FeatureExtractor(), 
                'target_size':VGG16_TARGET_SIZE,
                'current_class':current_class,
                'use_sara':False,
                }

    # Creating the environment
    env = gym.make('DetectionEnv-v0-Train', env_config=env_config)

    # Setting name
    name = "Normal DQN - Random Explore - VGG16 - No SaRa"

    # Creating the Replay_Buffer
    replay_buffer = Replay_Buffer(env)

    # Creating the DQN agent
    dqn_agent = DQNAgent(env, replay_buffer, name=name, exploration_mode=RANDOM_EXPLORE)

    # Running the agent
    dqn_agent.run()

    # Retrieving the episode info
    dqn_episode_info = dqn_agent.get_episode_info()

    # Printing the time taken to train the agent
    print("Time taken to train the agent: {:.2f} seconds".format(dqn_episode_info["eps_duration"]))

    # Saving the model
    dqn_agent.save(path="evaluation_models/" + name + '/' + current_class)

    # Closing the environment
    env.close()

    # Memory Cleaning
    del env, replay_buffer, dqn_agent, dqn_episode_info
# Out:
# **************************************************
# Executing for class: cat
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: cat
# ****************************************************************************************************
# Epoch 1 done for class cat.
# ****************************************************************************************************
# Episode: 1000 Epsilon: 0.37 Average Reward: -0.23748030669866146 Episode Length: 40 Average IoU: 0.44 Average Recall: 0.61 Epochs: 1 Final IoU: 0.46
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 2 done for class cat.
# ****************************************************************************************************
# Episode: 2000 Epsilon: 0.14 Average Reward: 2.8709583949616557 Episode Length: 1 Average IoU: 0.44 Average Recall: 0.62 Epochs: 2 Final IoU: 0.56
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 3 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class cat.
# ****************************************************************************************************
# Episode: 3000 Epsilon: 0.05 Average Reward: 2.3550731503357802 Episode Length: 40 Average IoU: 0.44 Average Recall: 0.62 Epochs: 4 Final IoU: 0.36
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 5 done for class cat.
# ****************************************************************************************************
# Episode: 4000 Epsilon: 0.02 Average Reward: 3.615076857767509 Episode Length: 2 Average IoU: 0.44 Average Recall: 0.61 Epochs: 5 Final IoU: 0.63
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 6 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class cat.
# ****************************************************************************************************
# Episode: 5000 Epsilon: 0.01 Average Reward: 2.783587439262366 Episode Length: 40 Average IoU: 0.44 Average Recall: 0.62 Epochs: 7 Final IoU: 0.70
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 8 done for class cat.
# ****************************************************************************************************
# Episode: 6000 Epsilon: 0.01 Average Reward: 4.175371426189583 Episode Length: 16 Average IoU: 0.44 Average Recall: 0.62 Epochs: 8 Final IoU: 0.65
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 9 done for class cat.
# ****************************************************************************************************
# Episode: 7000 Epsilon: 0.01 Average Reward: 2.8094542949198744 Episode Length: 28 Average IoU: 0.44 Average Recall: 0.61 Epochs: 9 Final IoU: 0.54
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 10 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class cat.
# ****************************************************************************************************
# Episode: 8000 Epsilon: 0.01 Average Reward: 4.546299384600776 Episode Length: 1 Average IoU: 0.44 Average Recall: 0.61 Epochs: 11 Final IoU: 0.61
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 12 done for class cat.
# ****************************************************************************************************
# Episode: 9000 Epsilon: 0.01 Average Reward: 4.3810808238775865 Episode Length: 40 Average IoU: 0.44 Average Recall: 0.61 Epochs: 12 Final IoU: 0.51
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 13 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class cat.
# ****************************************************************************************************
# Episode: 10000 Epsilon: 0.01 Average Reward: 3.9133650092953185 Episode Length: 40 Average IoU: 0.44 Average Recall: 0.61 Epochs: 14 Final IoU: 0.54
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 15 done for class cat.
# ****************************************************************************************************
# Completed 10565 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 1611.21 seconds
# **************************************************
# Executing for class: bird
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: bird
# ****************************************************************************************************
# Epoch 1 done for class bird.
# ****************************************************************************************************
# Episode: 1000 Epsilon: 0.37 Average Reward: 1.247779737352903 Episode Length: 25 Average IoU: 0.39 Average Recall: 0.58 Epochs: 1 Final IoU: 0.39
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 2 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class bird.
# ****************************************************************************************************
# Episode: 2000 Epsilon: 0.14 Average Reward: 0.7953164298900116 Episode Length: 14 Average IoU: 0.42 Average Recall: 0.60 Epochs: 3 Final IoU: 0.59
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 4 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class bird.
# ****************************************************************************************************
# Episode: 3000 Epsilon: 0.05 Average Reward: 2.1154907786382973 Episode Length: 40 Average IoU: 0.42 Average Recall: 0.60 Epochs: 5 Final IoU: 0.35
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 6 done for class bird.
# ****************************************************************************************************
# Episode: 4000 Epsilon: 0.02 Average Reward: 3.211427857794936 Episode Length: 40 Average IoU: 0.43 Average Recall: 0.60 Epochs: 6 Final IoU: 0.23
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 7 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class bird.
# ****************************************************************************************************
# Episode: 5000 Epsilon: 0.01 Average Reward: 3.63810289815852 Episode Length: 2 Average IoU: 0.44 Average Recall: 0.60 Epochs: 8 Final IoU: 0.45
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 9 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class bird.
# ****************************************************************************************************
# Episode: 6000 Epsilon: 0.01 Average Reward: 2.047055521968371 Episode Length: 40 Average IoU: 0.44 Average Recall: 0.61 Epochs: 10 Final IoU: 0.33
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 11 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class bird.
# ****************************************************************************************************
# Episode: 7000 Epsilon: 0.01 Average Reward: 4.320944016163661 Episode Length: 40 Average IoU: 0.44 Average Recall: 0.61 Epochs: 12 Final IoU: 0.37
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 13 done for class bird.
# ****************************************************************************************************
# Episode: 8000 Epsilon: 0.01 Average Reward: 5.158033174120763 Episode Length: 2 Average IoU: 0.45 Average Recall: 0.61 Epochs: 13 Final IoU: 0.63
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 14 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class bird.
# ****************************************************************************************************
# Completed 8690 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 1989.61 seconds
# **************************************************
# Executing for class: motorbike
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: motorbike
# ****************************************************************************************************
# Epoch 1 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class motorbike.
# ****************************************************************************************************
# Episode: 1000 Epsilon: 0.37 Average Reward: -0.44825527635618384 Episode Length: 20 Average IoU: 0.40 Average Recall: 0.58 Epochs: 2 Final IoU: 0.53
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 3 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class motorbike.
# ****************************************************************************************************
# Episode: 2000 Epsilon: 0.14 Average Reward: 2.2934959217444746 Episode Length: 1 Average IoU: 0.40 Average Recall: 0.58 Epochs: 5 Final IoU: 0.65
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 6 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class motorbike.
# ****************************************************************************************************
# Episode: 3000 Epsilon: 0.05 Average Reward: 5.150608958738785 Episode Length: 1 Average IoU: 0.40 Average Recall: 0.58 Epochs: 7 Final IoU: 0.52
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 8 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class motorbike.
# ****************************************************************************************************
# Episode: 4000 Epsilon: 0.02 Average Reward: 6.723398493786995 Episode Length: 4 Average IoU: 0.40 Average Recall: 0.57 Epochs: 10 Final IoU: 0.48
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 11 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class motorbike.
# ****************************************************************************************************
# Episode: 5000 Epsilon: 0.01 Average Reward: 7.265279905934787 Episode Length: 1 Average IoU: 0.40 Average Recall: 0.57 Epochs: 12 Final IoU: 0.63
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 13 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class motorbike.
# ****************************************************************************************************
# Completed 5925 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 832.23 seconds
# **************************************************
# Executing for class: diningtable
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: diningtable
# ****************************************************************************************************
# Epoch 1 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class diningtable.
# ****************************************************************************************************
# Episode: 1000 Epsilon: 0.37 Average Reward: 1.6268176680523196 Episode Length: 12 Average IoU: 0.34 Average Recall: 0.47 Epochs: 2 Final IoU: 0.40
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 3 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class diningtable.
# ****************************************************************************************************
# Episode: 2000 Epsilon: 0.14 Average Reward: 15.410384702143064 Episode Length: 40 Average IoU: 0.36 Average Recall: 0.49 Epochs: 4 Final IoU: 0.38
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 5 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class diningtable.
# ****************************************************************************************************
# Episode: 3000 Epsilon: 0.05 Average Reward: 16.94975651108458 Episode Length: 40 Average IoU: 0.37 Average Recall: 0.49 Epochs: 6 Final IoU: 0.36
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 7 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class diningtable.
# ****************************************************************************************************
# Episode: 4000 Epsilon: 0.02 Average Reward: 18.28040571728748 Episode Length: 40 Average IoU: 0.37 Average Recall: 0.49 Epochs: 8 Final IoU: 0.25
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 9 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class diningtable.
# ****************************************************************************************************
# Episode: 5000 Epsilon: 0.01 Average Reward: 20.668368412995598 Episode Length: 40 Average IoU: 0.36 Average Recall: 0.49 Epochs: 11 Final IoU: 0.33
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 12 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class diningtable.
# ****************************************************************************************************
# Episode: 6000 Epsilon: 0.01 Average Reward: 21.311602578765143 Episode Length: 40 Average IoU: 0.37 Average Recall: 0.50 Epochs: 13 Final IoU: 0.21
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 14 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class diningtable.
# ****************************************************************************************************
# Completed 6696 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 1546.50 seconds
# **************************************************
# Executing for class: train
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: train
# ****************************************************************************************************
# Epoch 1 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class train.
# ****************************************************************************************************
# Episode: 1000 Epsilon: 0.37 Average Reward: 0.24748964632759957 Episode Length: 21 Average IoU: 0.44 Average Recall: 0.61 Epochs: 2 Final IoU: 0.34
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 3 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class train.
# ****************************************************************************************************
# Episode: 2000 Epsilon: 0.14 Average Reward: 2.621270433145456 Episode Length: 1 Average IoU: 0.46 Average Recall: 0.63 Epochs: 5 Final IoU: 0.57
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 6 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class train.
# ****************************************************************************************************
# Episode: 3000 Epsilon: 0.05 Average Reward: 4.067252323776114 Episode Length: 40 Average IoU: 0.46 Average Recall: 0.64 Epochs: 7 Final IoU: 0.57
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 8 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class train.
# ****************************************************************************************************
# Episode: 4000 Epsilon: 0.02 Average Reward: 5.277940071219332 Episode Length: 1 Average IoU: 0.47 Average Recall: 0.64 Epochs: 10 Final IoU: 0.61
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 11 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class train.
# ****************************************************************************************************
# Episode: 5000 Epsilon: 0.01 Average Reward: 4.697256172329592 Episode Length: 7 Average IoU: 0.47 Average Recall: 0.65 Epochs: 12 Final IoU: 0.43
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 13 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class train.
# ****************************************************************************************************
# Episode: 6000 Epsilon: 0.01 Average Reward: 5.825670400226216 Episode Length: 1 Average IoU: 0.47 Average Recall: 0.65 Epochs: 14 Final IoU: 0.39
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 15 done for class train.
# ****************************************************************************************************
# Completed 6006 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 929.50 seconds
# **************************************************
# Executing for class: tvmonitor
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: tvmonitor
# ****************************************************************************************************
# Epoch 1 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class tvmonitor.
# ****************************************************************************************************
# Episode: 1000 Epsilon: 0.37 Average Reward: -1.1810264666210406 Episode Length: 2 Average IoU: 0.26 Average Recall: 0.52 Epochs: 2 Final IoU: 0.12
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 3 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class tvmonitor.
# ****************************************************************************************************
# Episode: 2000 Epsilon: 0.14 Average Reward: 1.4970813655645463 Episode Length: 3 Average IoU: 0.27 Average Recall: 0.53 Epochs: 4 Final IoU: 0.40
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 5 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class tvmonitor.
# ****************************************************************************************************
# Episode: 3000 Epsilon: 0.05 Average Reward: 2.8963081010152876 Episode Length: 40 Average IoU: 0.28 Average Recall: 0.53 Epochs: 6 Final IoU: 0.60
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 7 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class tvmonitor.
# ****************************************************************************************************
# Episode: 4000 Epsilon: 0.02 Average Reward: 6.04855967367337 Episode Length: 2 Average IoU: 0.29 Average Recall: 0.55 Epochs: 9 Final IoU: 0.53
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 10 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class tvmonitor.
# ****************************************************************************************************
# Episode: 5000 Epsilon: 0.01 Average Reward: 5.148466208450773 Episode Length: 40 Average IoU: 0.29 Average Recall: 0.56 Epochs: 11 Final IoU: 0.39
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 12 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class tvmonitor.
# ****************************************************************************************************
# Episode: 6000 Epsilon: 0.01 Average Reward: 7.644869535886582 Episode Length: 40 Average IoU: 0.30 Average Recall: 0.56 Epochs: 13 Final IoU: 0.65
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 14 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class tvmonitor.
# ****************************************************************************************************
# Completed 6619 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 1786.53 seconds
# **************************************************
# Executing for class: bus
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: bus
# ****************************************************************************************************
# Epoch 1 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class bus.
# ****************************************************************************************************
# Episode: 1000 Epsilon: 0.37 Average Reward: 0.8592853075217348 Episode Length: 12 Average IoU: 0.39 Average Recall: 0.59 Epochs: 3 Final IoU: 0.45
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 4 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class bus.
# ****************************************************************************************************
# Episode: 2000 Epsilon: 0.14 Average Reward: 3.7742200221457454 Episode Length: 40 Average IoU: 0.40 Average Recall: 0.60 Epochs: 6 Final IoU: 0.52
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 7 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class bus.
# ****************************************************************************************************
# Episode: 3000 Epsilon: 0.05 Average Reward: 5.636721917784681 Episode Length: 40 Average IoU: 0.40 Average Recall: 0.61 Epochs: 9 Final IoU: 0.23
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 10 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class bus.
# ****************************************************************************************************
# Episode: 4000 Epsilon: 0.02 Average Reward: 6.590733590060019 Episode Length: 40 Average IoU: 0.41 Average Recall: 0.61 Epochs: 12 Final IoU: 0.24
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 13 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class bus.
# ****************************************************************************************************
# Completed 4749 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 705.48 seconds
# **************************************************
# Executing for class: horse
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: horse
# ****************************************************************************************************
# Epoch 1 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class horse.
# ****************************************************************************************************
# Episode: 1000 Epsilon: 0.37 Average Reward: 0.9495781568160091 Episode Length: 40 Average IoU: 0.44 Average Recall: 0.63 Epochs: 2 Final IoU: 0.56
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 3 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class horse.
# ****************************************************************************************************
# Episode: 2000 Epsilon: 0.14 Average Reward: 2.9241412153456796 Episode Length: 1 Average IoU: 0.46 Average Recall: 0.65 Epochs: 5 Final IoU: 0.53
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 6 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class horse.
# ****************************************************************************************************
# Episode: 3000 Epsilon: 0.05 Average Reward: 4.267152951463413 Episode Length: 31 Average IoU: 0.46 Average Recall: 0.64 Epochs: 7 Final IoU: 0.47
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 8 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class horse.
# ****************************************************************************************************
# Episode: 4000 Epsilon: 0.02 Average Reward: 6.211695345792938 Episode Length: 9 Average IoU: 0.47 Average Recall: 0.65 Epochs: 10 Final IoU: 0.67
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 11 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class horse.
# ****************************************************************************************************
# Episode: 5000 Epsilon: 0.01 Average Reward: 5.656475185855201 Episode Length: 40 Average IoU: 0.47 Average Recall: 0.65 Epochs: 13 Final IoU: 0.38
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 14 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class horse.
# ****************************************************************************************************
# Completed 5699 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 828.40 seconds
# **************************************************
# Executing for class: car
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# ...
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: cow
# ****************************************************************************************************
# Epoch 1 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class cow.
# ****************************************************************************************************
# Episode: 1000 Epsilon: 0.37 Average Reward: 1.6714879495159587 Episode Length: 5 Average IoU: 0.41 Average Recall: 0.65 Epochs: 4 Final IoU: 0.57
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 5 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class cow.
# ****************************************************************************************************
# Episode: 2000 Epsilon: 0.14 Average Reward: 3.7720521271561513 Episode Length: 4 Average IoU: 0.43 Average Recall: 0.66 Epochs: 8 Final IoU: 0.53
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 9 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class cow.
# ****************************************************************************************************
# Episode: 3000 Epsilon: 0.05 Average Reward: 7.2150689471353395 Episode Length: 9 Average IoU: 0.44 Average Recall: 0.67 Epochs: 13 Final IoU: 0.53
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 14 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class cow.
# ****************************************************************************************************
# Completed 3359 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 449.24 seconds
# **************************************************
# Executing for class: sheep
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: sheep
# ****************************************************************************************************
# Epoch 1 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class sheep.
# ****************************************************************************************************
# Episode: 1000 Epsilon: 0.37 Average Reward: 1.6876257876514922 Episode Length: 1 Average IoU: 0.40 Average Recall: 0.66 Epochs: 4 Final IoU: 0.44
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 5 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class sheep.
# ****************************************************************************************************
# Episode: 2000 Epsilon: 0.14 Average Reward: 3.7819263443147877 Episode Length: 7 Average IoU: 0.43 Average Recall: 0.68 Epochs: 9 Final IoU: 0.36
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 10 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class sheep.
# ****************************************************************************************************
# Episode: 3000 Epsilon: 0.05 Average Reward: 6.9268431336657965 Episode Length: 40 Average IoU: 0.44 Average Recall: 0.68 Epochs: 13 Final IoU: 0.25
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 14 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class sheep.
# ****************************************************************************************************
# Completed 3268 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 413.32 seconds
# **************************************************
# Executing for class: sofa
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: sofa
# ****************************************************************************************************
# Epoch 1 done for class sofa.
# ****************************************************************************************************
# Episode: 1000 Epsilon: 0.37 Average Reward: 1.611073868177006 Episode Length: 12 Average IoU: 0.36 Average Recall: 0.49 Epochs: 1 Final IoU: 0.55
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 2 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class sofa.
# ****************************************************************************************************
# Episode: 2000 Epsilon: 0.14 Average Reward: 6.384842383703285 Episode Length: 10 Average IoU: 0.37 Average Recall: 0.51 Epochs: 3 Final IoU: 0.29
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 4 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class sofa.
# ****************************************************************************************************
# Episode: 3000 Epsilon: 0.05 Average Reward: 6.399490347121271 Episode Length: 4 Average IoU: 0.37 Average Recall: 0.53 Epochs: 5 Final IoU: 0.56
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 6 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class sofa.
# ****************************************************************************************************
# Episode: 4000 Epsilon: 0.02 Average Reward: 8.269387450172836 Episode Length: 40 Average IoU: 0.37 Average Recall: 0.54 Epochs: 7 Final IoU: 0.15
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 8 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class sofa.
# ****************************************************************************************************
# Episode: 5000 Epsilon: 0.01 Average Reward: 13.263171607446232 Episode Length: 3 Average IoU: 0.37 Average Recall: 0.54 Epochs: 9 Final IoU: 0.70
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 10 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class sofa.
# ****************************************************************************************************
# Episode: 6000 Epsilon: 0.01 Average Reward: 10.868508847679028 Episode Length: 40 Average IoU: 0.37 Average Recall: 0.54 Epochs: 11 Final IoU: 0.38
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 12 done for class sofa.
# ****************************************************************************************************
# Episode: 7000 Epsilon: 0.01 Average Reward: 10.105761136634584 Episode Length: 1 Average IoU: 0.37 Average Recall: 0.55 Epochs: 12 Final IoU: 0.54
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 13 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class sofa.
# ****************************************************************************************************
# Episode: 8000 Epsilon: 0.01 Average Reward: 13.061010947637188 Episode Length: 40 Average IoU: 0.37 Average Recall: 0.55 Epochs: 14 Final IoU: 0.24
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# Epoch 15 done for class sofa.
# ****************************************************************************************************
# Completed 8180 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 1577.82 seconds

# %% [markdown]
# **<h4> Normal DQN Agent - Random Exploration - VGG16 - with SaRa </h4>**

# %%
# Iterating over the classes
for current_class in classes:
    # Printing the class name
    print('*'*50)
    print('\033[92m' + 'Executing for class: ' + current_class + '\033[0m')
    print('*'*50)

    # Setting the environment configuration
    env_config = {'dataset': '../Datasets/PascalVOC2007_2012Dataset',
                'dataset_year': '2007+2012',
                'dataset_image_set': 'train',
                'feature_extractor':VGG16FeatureExtractor(), 
                'target_size':VGG16_TARGET_SIZE,
                'current_class':current_class,
                'use_sara':True,
                }

    # Creating the environment
    env = gym.make('DetectionEnv-v0-Train', env_config=env_config)

    # Setting name
    name = "Normal DQN - Random Explore - VGG16 - With SaRa"

    # Creating the Replay_Buffer
    replay_buffer = Replay_Buffer(env)

    # Creating the DQN agent
    dqn_agent = DQNAgent(env, replay_buffer, name=name, exploration_mode=RANDOM_EXPLORE)

    # Running the agent
    dqn_agent.run()

    # Retrieving the episode info
    dqn_episode_info = dqn_agent.get_episode_info()

    # Printing the time taken to train the agent
    print("Time taken to train the agent: {:.2f} seconds".format(dqn_episode_info["eps_duration"]))

    # Saving the model
    dqn_agent.save(path="evaluation_models/" + name + '/' + current_class)

    # Closing the environment
    env.close()

    # Memory Cleaning
    del env, replay_buffer, dqn_agent, dqn_episode_info
# Out:
# **************************************************
# Executing for class: cat
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: cat
# ****************************************************************************************************
# Epoch 1 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class cat.
# ****************************************************************************************************
# Completed 10556 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 2965.48 seconds
# **************************************************
# Executing for class: bird
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: bird
# ****************************************************************************************************
# Epoch 1 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class bird.
# ****************************************************************************************************
# Completed 8683 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 3266.05 seconds
# **************************************************
# Executing for class: motorbike
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: motorbike
# ****************************************************************************************************
# Epoch 1 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class motorbike.
# ****************************************************************************************************
# Completed 5924 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 1364.28 seconds
# **************************************************
# Executing for class: diningtable
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: diningtable
# ****************************************************************************************************
# Epoch 1 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class diningtable.
# ****************************************************************************************************
# Completed 6688 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 1890.25 seconds
# **************************************************
# Executing for class: train
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: train
# ****************************************************************************************************
# Epoch 1 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class train.
# ****************************************************************************************************
# Completed 6022 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 1351.35 seconds
# **************************************************
# Executing for class: tvmonitor
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: tvmonitor
# ****************************************************************************************************
# Epoch 1 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class tvmonitor.
# ****************************************************************************************************
# Completed 6620 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 1967.92 seconds
# **************************************************
# Executing for class: bus
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: bus
# ****************************************************************************************************
# Epoch 1 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class bus.
# ****************************************************************************************************
# Completed 4764 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 1085.84 seconds
# **************************************************
# Executing for class: horse
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: horse
# ****************************************************************************************************
# Epoch 1 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class horse.
# ****************************************************************************************************
# Completed 5701 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 1150.26 seconds
# **************************************************
# Executing for class: car
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: car
# ****************************************************************************************************
# Epoch 1 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class car.
# ****************************************************************************************************
# Completed 15321 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 4848.52 seconds
# **************************************************
# Executing for class: pottedplant
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: pottedplant
# ****************************************************************************************************
# Epoch 1 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class pottedplant.
# ****************************************************************************************************
# Completed 6598 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 2057.86 seconds
# **************************************************
# Executing for class: person
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: person
# ****************************************************************************************************
# Epoch 1 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class person.
# ...
# Epoch 4 done for class aeroplane.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class aeroplane.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class aeroplane.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class aeroplane.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class aeroplane.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class aeroplane.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class aeroplane.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class aeroplane.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class aeroplane.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class aeroplane.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class aeroplane.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class aeroplane.
# ****************************************************************************************************
# Completed 6589 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 1444.73 seconds
# **************************************************
# Executing for class: cow
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: cow
# ****************************************************************************************************
# Epoch 1 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class cow.
# ****************************************************************************************************
# Completed 3357 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 771.85 seconds
# **************************************************
# Executing for class: sheep
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: sheep
# ****************************************************************************************************
# Epoch 1 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class sheep.
# ****************************************************************************************************
# Completed 3278 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 725.11 seconds
# **************************************************
# Executing for class: sofa
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: sofa
# ****************************************************************************************************
# Epoch 1 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class sofa.
# ****************************************************************************************************
# Completed 8170 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 2308.29 seconds

# %% [markdown]
# **<h4> Normal DQN Agent - Guided Exploration - VGG16 - No SaRa </h4>**

# %%
# Iterating over the classes
for current_class in classes:
    # Printing the class name
    print('*'*50)
    print('\033[92m' + 'Executing for class: ' + current_class + '\033[0m')
    print('*'*50)

    # Setting the environment configuration
    env_config = {'dataset': '../Datasets/PascalVOC2007_2012Dataset',
                'dataset_year': '2007+2012',
                'dataset_image_set': 'train',
                'feature_extractor':VGG16FeatureExtractor(), 
                'target_size':VGG16_TARGET_SIZE,
                'current_class':current_class,
                'use_sara':False,
                }

    # Creating the environment
    env = gym.make('DetectionEnv-v0-Train', env_config=env_config)

    # Setting name
    name = "Normal DQN - Guided Explore - VGG16 - No SaRa"

    # Creating the Replay_Buffer
    replay_buffer = Replay_Buffer(env)

    # Creating the DQN agent
    dqn_agent = DQNAgent(env, replay_buffer, name=name, exploration_mode=GUIDED_EXPLORE)

    # Running the agent
    dqn_agent.run()

    # Retrieving the episode info
    dqn_episode_info = dqn_agent.get_episode_info()

    # Printing the time taken to train the agent
    print("Time taken to train the agent: {:.2f} seconds".format(dqn_episode_info["eps_duration"]))

    # Saving the model
    dqn_agent.save(path="evaluation_models/" + name + '/' + current_class)

    # Closing the environment
    env.close()

    # Memory Cleaning
    del env, replay_buffer, dqn_agent, dqn_episode_info
# Out:
# **************************************************
# Executing for class: cat
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: cat
# ****************************************************************************************************
# Epoch 1 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class cat.
# ****************************************************************************************************
# Completed 10558 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 1433.58 seconds
# **************************************************
# Executing for class: bird
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: bird
# ****************************************************************************************************
# Epoch 1 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class bird.
# ****************************************************************************************************
# Completed 8691 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 1746.41 seconds
# **************************************************
# Executing for class: motorbike
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: motorbike
# ****************************************************************************************************
# Epoch 1 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class motorbike.
# ****************************************************************************************************
# Completed 5928 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 834.15 seconds
# **************************************************
# Executing for class: diningtable
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: diningtable
# ****************************************************************************************************
# Epoch 1 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class diningtable.
# ****************************************************************************************************
# Completed 6692 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 1597.03 seconds
# **************************************************
# Executing for class: train
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: train
# ****************************************************************************************************
# Epoch 1 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class train.
# ****************************************************************************************************
# Completed 6007 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 680.54 seconds
# **************************************************
# Executing for class: tvmonitor
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: tvmonitor
# ****************************************************************************************************
# Epoch 1 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class tvmonitor.
# ****************************************************************************************************
# Completed 6614 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 1385.38 seconds
# **************************************************
# Executing for class: bus
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: bus
# ****************************************************************************************************
# Epoch 1 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class bus.
# ****************************************************************************************************
# Completed 4759 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 558.26 seconds
# **************************************************
# Executing for class: horse
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: horse
# ****************************************************************************************************
# Epoch 1 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class horse.
# ****************************************************************************************************
# Completed 5698 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 750.91 seconds
# **************************************************
# Executing for class: car
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: car
# ****************************************************************************************************
# Epoch 1 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class car.
# ****************************************************************************************************
# Completed 15311 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 3130.01 seconds
# **************************************************
# Executing for class: pottedplant
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: pottedplant
# ****************************************************************************************************
# Epoch 1 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class pottedplant.
# ****************************************************************************************************
# Completed 6604 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 1484.77 seconds
# **************************************************
# Executing for class: person
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: person
# ****************************************************************************************************
# Epoch 1 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class person.
# ...
# Epoch 4 done for class aeroplane.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class aeroplane.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class aeroplane.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class aeroplane.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class aeroplane.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class aeroplane.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class aeroplane.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class aeroplane.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class aeroplane.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class aeroplane.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class aeroplane.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class aeroplane.
# ****************************************************************************************************
# Completed 6584 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 602.25 seconds
# **************************************************
# Executing for class: cow
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: cow
# ****************************************************************************************************
# Epoch 1 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class cow.
# ****************************************************************************************************
# Completed 3363 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 383.66 seconds
# **************************************************
# Executing for class: sheep
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: sheep
# ****************************************************************************************************
# Epoch 1 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class sheep.
# ****************************************************************************************************
# Completed 3273 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 414.33 seconds
# **************************************************
# Executing for class: sofa
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: sofa
# ****************************************************************************************************
# Epoch 1 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class sofa.
# ****************************************************************************************************
# Completed 8179 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 1590.85 seconds

# %% [markdown]
# **<h4> Normal DQN Agent - Guided Exploration - VGG16 - With SaRa </h4>**

# %%
# Iterating over the classes
for current_class in classes:
    # Printing the class name
    print('*'*50)
    print('\033[92m' + 'Executing for class: ' + current_class + '\033[0m')
    print('*'*50)

    # Setting the environment configuration
    env_config = {'dataset': '../Datasets/PascalVOC2007_2012Dataset',
                'dataset_year': '2007+2012',
                'dataset_image_set': 'train',
                'feature_extractor':VGG16FeatureExtractor(), 
                'target_size':VGG16_TARGET_SIZE,
                'current_class':current_class,
                'use_sara':True,
                }

    # Creating the environment
    env = gym.make('DetectionEnv-v0-Train', env_config=env_config)

    # Setting name
    name = "Normal DQN - Guided Explore - VGG16 - With SaRa"

    # Creating the Replay_Buffer
    replay_buffer = Replay_Buffer(env)

    # Creating the DQN agent
    dqn_agent = DQNAgent(env, replay_buffer, name=name, exploration_mode=GUIDED_EXPLORE)

    # Running the agent
    dqn_agent.run()

    # Retrieving the episode info
    dqn_episode_info = dqn_agent.get_episode_info()

    # Printing the time taken to train the agent
    print("Time taken to train the agent: {:.2f} seconds".format(dqn_episode_info["eps_duration"]))

    # Saving the model
    dqn_agent.save(path="evaluation_models/" + name + '/' + current_class)

    # Closing the environment
    env.close()

    # Memory Cleaning
    del env, replay_buffer, dqn_agent, dqn_episode_info
# Out:
# **************************************************
# Executing for class: cat
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: cat
# ****************************************************************************************************
# Epoch 1 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class cat.
# ****************************************************************************************************
# Completed 10563 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 2780.71 seconds
# **************************************************
# Executing for class: bird
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: bird
# ****************************************************************************************************
# Epoch 1 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class bird.
# ****************************************************************************************************
# Completed 8688 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 2658.06 seconds
# **************************************************
# Executing for class: motorbike
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: motorbike
# ****************************************************************************************************
# Epoch 1 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class motorbike.
# ****************************************************************************************************
# Completed 5928 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 1506.40 seconds
# **************************************************
# Executing for class: diningtable
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: diningtable
# ****************************************************************************************************
# Epoch 1 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class diningtable.
# ****************************************************************************************************
# Completed 6693 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 1940.98 seconds
# **************************************************
# Executing for class: train
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: train
# ****************************************************************************************************
# Epoch 1 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class train.
# ****************************************************************************************************
# Completed 6021 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 1538.08 seconds
# **************************************************
# Executing for class: tvmonitor
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: tvmonitor
# ****************************************************************************************************
# Epoch 1 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class tvmonitor.
# ****************************************************************************************************
# Completed 6612 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 1985.26 seconds
# **************************************************
# Executing for class: bus
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: bus
# ****************************************************************************************************
# Epoch 1 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class bus.
# ****************************************************************************************************
# Completed 4755 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 1243.72 seconds
# **************************************************
# Executing for class: horse
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: horse
# ****************************************************************************************************
# Epoch 1 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class horse.
# ****************************************************************************************************
# Completed 5703 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 1483.01 seconds
# **************************************************
# Executing for class: car
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: car
# ****************************************************************************************************
# Epoch 1 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class car.
# ****************************************************************************************************
# Completed 15316 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 5102.57 seconds
# **************************************************
# Executing for class: pottedplant
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: pottedplant
# ****************************************************************************************************
# Epoch 1 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class pottedplant.
# ****************************************************************************************************
# Completed 6593 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 2159.13 seconds
# **************************************************
# Executing for class: person
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: person
# ****************************************************************************************************
# Epoch 1 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class person.
# ...
# Epoch 4 done for class aeroplane.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class aeroplane.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class aeroplane.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class aeroplane.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class aeroplane.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class aeroplane.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class aeroplane.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class aeroplane.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class aeroplane.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class aeroplane.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class aeroplane.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class aeroplane.
# ****************************************************************************************************
# Completed 6585 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 1683.94 seconds
# **************************************************
# Executing for class: cow
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: cow
# ****************************************************************************************************
# Epoch 1 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class cow.
# ****************************************************************************************************
# Completed 3361 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 751.74 seconds
# **************************************************
# Executing for class: sheep
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: sheep
# ****************************************************************************************************
# Epoch 1 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class sheep.
# ****************************************************************************************************
# Completed 3269 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 750.19 seconds
# **************************************************
# Executing for class: sofa
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: sofa
# ****************************************************************************************************
# Epoch 1 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class sofa.
# ****************************************************************************************************
# Completed 8176 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 2655.07 seconds

# %% [markdown]
# **<h3> Training Experiment 2: Feature Learning Architectures </h3>**

# %% [markdown]
# **<h4> Normal DQN Agent - Random Exploration - MobileNet - No SaRa </h4>**

# %%
# Iterating over the classes
for current_class in classes:
    # Printing the class name
    print('*'*50)
    print('\033[92m' + 'Executing for class: ' + current_class + '\033[0m')
    print('*'*50)

    # Setting the environment configuration
    env_config = {'dataset': '../Datasets/PascalVOC2007_2012Dataset',
                'dataset_year': '2007+2012',
                'dataset_image_set': 'train',
                'feature_extractor':MobileNetV2FeatureExtractor(), 
                'target_size':MOBILENETV2_TARGET_SIZE,
                'current_class':current_class,
                'use_sara':False,
                }

    # Creating the environment
    env = gym.make('DetectionEnv-v0-Train', env_config=env_config)

    # Setting name
    name = "Normal DQN - Random Explore - MobileNet - No SaRa"

    # Creating the Replay_Buffer
    replay_buffer = Replay_Buffer(env)

    # Creating the DQN agent
    dqn_agent = DQNAgent(env, replay_buffer, name=name, exploration_mode=RANDOM_EXPLORE)

    # Running the agent
    dqn_agent.run()

    # Retrieving the episode info
    dqn_episode_info = dqn_agent.get_episode_info()

    # Printing the time taken to train the agent
    print("Time taken to train the agent: {:.2f} seconds".format(dqn_episode_info["eps_duration"]))

    # Saving the model
    dqn_agent.save(path="evaluation_models/" + name + '/' + current_class)

    # Closing the environment
    env.close()

    # Memory Cleaning
    del env, replay_buffer, dqn_agent, dqn_episode_info
# Out:
# **************************************************
# Executing for class: cat
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: cat
# ****************************************************************************************************
# Epoch 1 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class cat.
# ****************************************************************************************************
# Completed 10560 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 1843.64 seconds
# **************************************************
# Executing for class: bird
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: bird
# ****************************************************************************************************
# Epoch 1 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class bird.
# ****************************************************************************************************
# Completed 8683 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 2083.88 seconds
# **************************************************
# Executing for class: motorbike
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: motorbike
# ****************************************************************************************************
# Epoch 1 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class motorbike.
# ****************************************************************************************************
# Completed 5923 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 1081.86 seconds
# **************************************************
# Executing for class: diningtable
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: diningtable
# ****************************************************************************************************
# Epoch 1 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class diningtable.
# ****************************************************************************************************
# Completed 6697 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 1916.91 seconds
# **************************************************
# Executing for class: train
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: train
# ****************************************************************************************************
# Epoch 1 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class train.
# ****************************************************************************************************
# Completed 6010 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 1010.93 seconds
# **************************************************
# Executing for class: tvmonitor
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: tvmonitor
# ****************************************************************************************************
# Epoch 1 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class tvmonitor.
# ****************************************************************************************************
# Completed 6611 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 2075.11 seconds
# **************************************************
# Executing for class: bus
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: bus
# ****************************************************************************************************
# Epoch 1 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class bus.
# ****************************************************************************************************
# Completed 4756 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 748.84 seconds
# **************************************************
# Executing for class: horse
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: horse
# ****************************************************************************************************
# Epoch 1 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class horse.
# ****************************************************************************************************
# Completed 5702 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 1002.21 seconds
# **************************************************
# Executing for class: car
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: car
# ****************************************************************************************************
# Epoch 1 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class car.
# ****************************************************************************************************
# Completed 15306 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 4292.43 seconds
# **************************************************
# Executing for class: pottedplant
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: pottedplant
# ****************************************************************************************************
# Epoch 1 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class pottedplant.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class pottedplant.
# ****************************************************************************************************
# Completed 6605 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 1992.42 seconds
# **************************************************
# Executing for class: person
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: person
# ****************************************************************************************************
# Epoch 1 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class person.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class person.
# ...
# Epoch 4 done for class aeroplane.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class aeroplane.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class aeroplane.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class aeroplane.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class aeroplane.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class aeroplane.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class aeroplane.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class aeroplane.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class aeroplane.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class aeroplane.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class aeroplane.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class aeroplane.
# ****************************************************************************************************
# Completed 6588 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 884.91 seconds
# **************************************************
# Executing for class: cow
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: cow
# ****************************************************************************************************
# Epoch 1 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class cow.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class cow.
# ****************************************************************************************************
# Completed 3352 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 632.53 seconds
# **************************************************
# Executing for class: sheep
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: sheep
# ****************************************************************************************************
# Epoch 1 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class sheep.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class sheep.
# ****************************************************************************************************
# Completed 3273 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 583.22 seconds
# **************************************************
# Executing for class: sofa
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: sofa
# ****************************************************************************************************
# Epoch 1 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class sofa.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class sofa.
# ****************************************************************************************************
# Completed 8182 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 2175.85 seconds

# %% [markdown]
# **<h4> Normal DQN Agent - Random Exploration - MobileNet - With SaRa </h4>**

# %%
# Iterating over the classes
for current_class in classes:
    # Printing the class name
    print('*'*50)
    print('\033[92m' + 'Executing for class: ' + current_class + '\033[0m')
    print('*'*50)

    # Setting the environment configuration
    env_config = {'dataset': '../Datasets/PascalVOC2007_2012Dataset',
                'dataset_year': '2007+2012',
                'dataset_image_set': 'train',
                'feature_extractor':MobileNetV2FeatureExtractor(), 
                'target_size':MOBILENETV2_TARGET_SIZE,
                'current_class':current_class,
                'use_sara':True,
                }

    # Creating the environment
    env = gym.make('DetectionEnv-v0-Train', env_config=env_config)

    # Setting name
    name = "Normal DQN - Random Explore - MobileNet - With SaRa"

    # Creating the Replay_Buffer
    replay_buffer = Replay_Buffer(env)

    # Creating the DQN agent
    dqn_agent = DQNAgent(env, replay_buffer, name=name, exploration_mode=RANDOM_EXPLORE)

    # Running the agent
    dqn_agent.run()

    # Retrieving the episode info
    dqn_episode_info = dqn_agent.get_episode_info()

    # Printing the time taken to train the agent
    print("Time taken to train the agent: {:.2f} seconds".format(dqn_episode_info["eps_duration"]))

    # Saving the model
    dqn_agent.save(path="evaluation_models/" + name + '/' + current_class)

    # Closing the environment
    env.close()

    # Memory Cleaning
    del env, replay_buffer, dqn_agent, dqn_episode_info

# %% [markdown]
# **<h4> Normal DQN Agent - Random Exploration - ResNet50 - No SaRa </h4>**

# %%
# Iterating over the classes
for current_class in classes:
    # Printing the class name
    print('*'*50)
    print('\033[92m' + 'Executing for class: ' + current_class + '\033[0m')
    print('*'*50)

    # Setting the environment configuration
    env_config = {'dataset': '../Datasets/PascalVOC2007_2012Dataset',
                'dataset_year': '2007+2012',
                'dataset_image_set': 'train',
                'feature_extractor':ResNet50FeatureExtractor(), 
                'target_size':RESNET50_TARGET_SIZE,
                'current_class':current_class,
                'use_sara':False,
                }

    # Creating the environment
    env = gym.make('DetectionEnv-v0-Train', env_config=env_config)

    # Setting name
    name = "Normal DQN - Random Explore - ResNet50 - No SaRa"

    # Creating the Replay_Buffer
    replay_buffer = Replay_Buffer(env)

    # Creating the DQN agent
    dqn_agent = DQNAgent(env, replay_buffer, name=name, exploration_mode=RANDOM_EXPLORE)

    # Running the agent
    dqn_agent.run()

    # Retrieving the episode info
    dqn_episode_info = dqn_agent.get_episode_info()

    # Printing the time taken to train the agent
    print("Time taken to train the agent: {:.2f} seconds".format(dqn_episode_info["eps_duration"]))

    # Saving the model
    dqn_agent.save(path="evaluation_models/" + name + '/' + current_class)

    # Closing the environment
    env.close()

    # Memory Cleaning
    del env, replay_buffer, dqn_agent, dqn_episode_info
# Out:
# **************************************************
# Executing for class: cat
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: cat
# ****************************************************************************************************
# Epoch 1 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class cat.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class cat.
# ****************************************************************************************************
# Completed 10560 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 2028.04 seconds
# **************************************************
# Executing for class: bird
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: bird
# ****************************************************************************************************
# Epoch 1 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class bird.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class bird.
# ****************************************************************************************************
# Completed 8687 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 2624.73 seconds
# **************************************************
# Executing for class: motorbike
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: motorbike
# ****************************************************************************************************
# Epoch 1 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class motorbike.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class motorbike.
# ****************************************************************************************************
# Completed 5923 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 1185.08 seconds
# **************************************************
# Executing for class: diningtable
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: diningtable
# ****************************************************************************************************
# Epoch 1 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class diningtable.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class diningtable.
# ****************************************************************************************************
# Completed 6686 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 1948.37 seconds
# **************************************************
# Executing for class: train
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: train
# ****************************************************************************************************
# Epoch 1 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class train.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class train.
# ****************************************************************************************************
# Completed 6012 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 1165.00 seconds
# **************************************************
# Executing for class: tvmonitor
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: tvmonitor
# ****************************************************************************************************
# Epoch 1 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class tvmonitor.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class tvmonitor.
# ****************************************************************************************************
# Completed 6611 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 2233.26 seconds
# **************************************************
# Executing for class: bus
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: bus
# ****************************************************************************************************
# Epoch 1 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class bus.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class bus.
# ****************************************************************************************************
# Completed 4754 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 834.71 seconds
# **************************************************
# Executing for class: horse
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: horse
# ****************************************************************************************************
# Epoch 1 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 3 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 4 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 5 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 6 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 7 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 8 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 9 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 10 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 11 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 12 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 13 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 14 done for class horse.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 15 done for class horse.
# ****************************************************************************************************
# Completed 5698 episodes!
# ----------------------------------------------------------------------------------------------------
# Time taken to train the agent: 1131.85 seconds
# **************************************************
# Executing for class: car
# **************************************************
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_06-Nov-2007.tar to ../Datasets/PascalVOC2007_2012Dataset
# Using downloaded and verified file: ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar
# Extracting ../Datasets/PascalVOC2007_2012Dataset\VOCtrainval_11-May-2012.tar to ../Datasets/PascalVOC2007_2012Dataset
# Dataset loaded successfully.
# Total number of classes in the dataset: 20
# Total number of images in the dataset: 12880
# Current Class: car
# ****************************************************************************************************
# Epoch 1 done for class car.
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch 2 done for class car.
# ****************************************************************************************************

# %% [markdown]
# **<h4> Normal DQN Agent - Random Exploration - ResNet50 - With SaRa </h4>**

# %%
# Iterating over the classes
for current_class in classes:
    # Printing the class name
    print('*'*50)
    print('\033[92m' + 'Executing for class: ' + current_class + '\033[0m')
    print('*'*50)

    # Setting the environment configuration
    env_config = {'dataset': '../Datasets/PascalVOC2007_2012Dataset',
                'dataset_year': '2007+2012',
                'dataset_image_set': 'train',
                'feature_extractor':ResNet50FeatureExtractor(), 
                'target_size':RESNET50_TARGET_SIZE,
                'current_class':current_class,
                'use_sara':True,
                }

    # Creating the environment
    env = gym.make('DetectionEnv-v0-Train', env_config=env_config)

    # Setting name
    name = "Normal DQN - Random Explore - ResNet50 - With SaRa"

    # Creating the Replay_Buffer
    replay_buffer = Replay_Buffer(env)

    # Creating the DQN agent
    dqn_agent = DQNAgent(env, replay_buffer, name=name, exploration_mode=RANDOM_EXPLORE)

    # Running the agent
    dqn_agent.run()

    # Retrieving the episode info
    dqn_episode_info = dqn_agent.get_episode_info()

    # Printing the time taken to train the agent
    print("Time taken to train the agent: {:.2f} seconds".format(dqn_episode_info["eps_duration"]))

    # Saving the model
    dqn_agent.save(path="evaluation_models/" + name + '/' + current_class)

    # Closing the environment
    env.close()

    # Memory Cleaning
    del env, replay_buffer, dqn_agent, dqn_episode_info
